# %%
from task_4.manipulator import Manipulator
from task_4.rotating_pair import RotatingPair
from task_4.sliding_pair import SlidingPair
from task_4.axis_type import AxisType

# %%
m = Manipulator()
m.add_pair(SlidingPair(AxisType.Z, speed=20, rest_current=4, move_current=12, length=200, value=50))
m.add_pair(RotatingPair(AxisType.X, speed=45, rest_current=5, move_current=15, length=100, value=90))

# %%
print(m)
# Out:
# Manipulator:
# |-⭡(Z)--200(мм)--⭯(X)--100(мм)--C

# %%
m.forward_kinematics(work_time_set=[3, 1])
m.forward_kinematics(work_time_set=[0, 1])
# Out:
# [array([0., 0., 0., 1.]),
#  array([  0.,   0., 200.,   1.]),
#  array([  0.        , -70.71067812, 270.71067812,   1.        ])]

# %%
print(m.positions)
# Out:
# [[array([0., 0., 0., 1.]), array([  0.,   0., 200.,   1.]), array([  0.,   0., 300.,   1.])], [array([0., 0., 0., 1.]), array([  0.,   0., 260.,   1.]), array([  0.        , -70.71067812, 330.71067812,   1.        ])], [array([0., 0., 0., 1.]), array([  0.,   0., 200.,   1.]), array([  0.        , -70.71067812, 270.71067812,   1.        ])]]

# %%
m.visualize_manipulator()
